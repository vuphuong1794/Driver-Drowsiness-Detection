# %% [markdown]
# ## 1. Install and Import Dependencies

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...

# %%
# !cd yolov5 & pip install -r requirements.txt

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2 
import requests
from PIL import Image
from io import BytesIO
import subprocess

# %% [markdown]
# ## 2. Load Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in C:\Users\TG/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2025-3-17 Python-3.12.7 torch-2.6.0+cu118 CPU
#
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 14.1M/14.1M [00:04<00:00, 3.53MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %% [markdown]
# ## 3. Make Detections

# %%
url = 'https://i.pinimg.com/736x/a4/bb/e5/a4bbe539c2a687f07453b117fc1196c9.jpg'

# %%
response = requests.get(url)
if response.status_code == 200:
    img = Image.open(BytesIO(response.content))  # Chuyển thành PIL.Image
else:
    raise Exception("Không thể tải ảnh từ URL")

# %%
results = model(img)
results.print()
# Out:
# C:\Users\TG/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# image 1/1: 1104x736 1 awake
# Speed: 76.0ms pre-process, 533.3ms inference, 5.0ms NMS per image at shape (1, 3, 640, 448)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %% [markdown]
# ## 4. Real Time Dectections and Object Dectection using Video

# %%
cap = cv2.VideoCapture(1) #cau hinh camera muon dung (0: laptop, 1: webcam)
while cap.isOpened(): # kiem tram webcam mo hay dong
    ret, frame = cap.read()
    #make detections
    results = model(frame)
    cv2.imshow('YOLO', np.squeeze(results.render())) 
    if cv2.waitKey(10) & 0xFF == ord('q'): # nhan phim enter de thoat
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\TG/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# C:\Users\TG/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# C:\Users\TG/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# C:\Users\TG/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# ...

# %% [markdown]
# ## 5. Train a Custom YOLO Model

# %%
import uuid # tao ma dinh danh duy nhat
import os
import time

# %%
IMAGES_PART = os.path.join('data', 'images') #data/images
labels = ['awake', 'drowsy'] # 2 trang thai tinh tao va buon ngu
number_imgs = 20

# %%
import cv2
import os
import time
import uuid

# Cấu hình tham số
IMAGES_PART = "data"  # Thư mục lưu ảnh
label = "drowsy"  # Chỉ thu thập hình ảnh buồn ngủ
number_imgs = 20  # Số lượng ảnh cần thu thập

# Tạo thư mục nếu chưa có
if not os.path.exists(IMAGES_PART):
    os.makedirs(IMAGES_PART)

cap = cv2.VideoCapture(1)  # 0: Laptop, 1: Webcam ngoài

print(f'Collecting images for {label}')
time.sleep(3)

for img_num in range(number_imgs):
    print(f'Collecting image {img_num + 1}/{number_imgs} for {label}')

    ret, frame = cap.read()
    if not ret:
        print("Không thể đọc hình ảnh từ camera!")
        break

    imgname = os.path.join(IMAGES_PART, f'{label}.{uuid.uuid1()}.jpg')
    cv2.imwrite(imgname, frame)

    cv2.imshow('Image Collection', frame)
    time.sleep(2)

    if cv2.waitKey(10) & 0xFF == ord('q'):  # Nhấn 'q' để thoát sớm
        break

cap.release()
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture(1) #cau hinh camera muon dung (0: laptop, 1: webcam)
for label in labels: # vong lap cua 2 trang thai
    print('Collecting images for {}'. format(label))
    time.sleep(5) 
    
    for img_num in range(number_imgs):  # thu thap 20 hinh anh cho moi trang thai
        print('Collecting images for {}, images number {}'.format(label, img_num))
        
        ret, frame = cap.read()
        
        imgname = os.path.join(IMAGES_PART, label+'.'+str(uuid.uuid1())+'.jpg') # dat ten cho anh thu duoc
        
        cv2.imwrite(imgname, frame)
        
        cv2.imshow('Image collection', frame)
        time.sleep(2)
        
        if cv2.waitKey(10) & 0xFF == ord('q'): # nhan phim enter de thoat
            break
            
cap.release()
cv2.destroyAllWindows()

# %%
# !git clone https://github.com/HumanSignal/labelImg
# Out:
# Cloning into 'labelImg'...

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resource.py resources.qrc

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 500 --data dataset.yaml --weights yolov5s.pt --worker 2
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=500, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data\hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5
# YOLOv5  v7.0-399-g8cc44963 Python-3.12.7 torch-2.6.0+cu118 CPU
#
# ...

# %% [markdown]
# ## 6. Detecting Drowsiness

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp/weights/best.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\TG/.cache\torch\hub\master.zip
# YOLOv5  2025-3-20 Python-3.12.7 torch-2.6.0+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
img = os.path.join('data', 'images', 'awake.8e70907c-0537-11f0-8323-38d57a1abf4e.jpg')

# %%
results = model(img)
# Out:
# C:\Users\TG/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):

# %%
results.print()
# Out:
# image 1/1: 480x640 1 awake
# Speed: 16.0ms pre-process, 165.2ms inference, 1.0ms NMS per image at shape (1, 3, 480, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
# !pip install pygame

# %%
import cv2
import numpy as np
import pygame
import threading

# Khởi tạo pygame
pygame.mixer.init()

cap = cv2.VideoCapture(1)  # Truy cập webcam
alarm_playing = False  # Biến kiểm tra xem âm thanh có đang phát không

def play_alarm():
    global alarm_playing
    pygame.mixer.music.load("alarm2.mp3")  # Load file âm thanh
    pygame.mixer.music.play(-1)  # Phát lặp lại vô hạn
    alarm_playing = True

def stop_alarm():
    global alarm_playing
    pygame.mixer.music.stop()  # Dừng phát âm thanh
    alarm_playing = False

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame)
    cv2.imshow('YOLO', np.squeeze(results.render()))

    drowsy_detected = False  # Cờ kiểm tra trạng thái buồn ngủ

    # Kiểm tra nếu phát hiện "drowsy" với confidence > 0.65
    for obj in results.pred[0]:  
        label = results.names[int(obj[5])]  
        confidence = obj[4]  # Lấy giá trị độ tin cậy

        if label == "drowsy" and confidence > 0.5:
            drowsy_detected = True
            if not alarm_playing:  # Nếu âm thanh chưa phát thì bắt đầu phát
                threading.Thread(target=play_alarm).start()

    # Nếu không còn phát hiện "drowsy" hoặc confidence không đạt ngưỡng thì dừng báo động
    if not drowsy_detected and alarm_playing:
        stop_alarm()  # Dừng âm thanh

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
pygame.mixer.quit()  # Đóng pygame mixer khi kết thúc chương trình
# Out:
# C:\Users\TG/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# C:\Users\TG/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# C:\Users\TG/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# C:\Users\TG/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# ...
